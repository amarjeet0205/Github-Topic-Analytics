# %% [markdown]
# In this project, I combined traditional web scraping using **BeautifulSoup** with **GitHub's REST API** to gather repository data by topic.
# # 🔧 Technologies Used:
# - `requests` – for making HTTP requests
# - `BeautifulSoup` – for parsing GitHub's HTML (to extract topic names and descriptions)
# - `GitHub REST API` – to fetch top repositories per topic
# - `pandas` – to organize and merge the data
# - `Power BI` – for dashboard visualization

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
from datetime import datetime
import time

# %%
def parse_star_count(star_str):
    star_str = star_str.replace(',', '')
    if 'k' in star_str:
        try:
            return int(float(star_str.replace('k', '')) * 1000)
        except ValueError:
            print(f"Failed to parse star count: {star_str}")
            return 0
    else:
        try:
            return int(float(star_str))
        except ValueError:
            print(f"Failed to parse star count: {star_str}")
            return 0

# %% [markdown]
# ## 🔍 Step 1: Scraping Topics using BeautifulSoup
#
# I scraped GitHub's Topics page using BeautifulSoup to extract:
# - Topic Name
# - Description
# - URL

# %%
# Manual mapping of problematic topic names
TOPIC_NAME_MAPPING = {
    "ASP.NET": "asp-net",
    "C++": "c-plus-plus",
    "C#": "c-sharp",
    ".NET": "dotnet",
    "The Julia Language": "julia",
    "Node.js": "nodejs",
    "Software-defined networking": "sdn"
}
# Function to normalize topic names
def normalize_topic_name(topic_name):
    # Use manual mapping if available
    if topic_name in TOPIC_NAME_MAPPING:
        return TOPIC_NAME_MAPPING[topic_name]
    
    # Default normalization: replace spaces with hyphens and convert to lowercase
    normalized_name = topic_name.lower().replace(' ', '-')
    return normalized_name

# %%
# Function to scrape all GitHub topics from the website
def get_all_topics():
    base_url = "https://github.com/topics"
    topics = []
    page = 1
    
    while True:
        print(f"Fetching topics from page {page}...")
        response = requests.get(f"{base_url}?page={page}", timeout=10)
        if response.status_code != 200:
            print("No more topics found.")
            break
        
        soup = BeautifulSoup(response.text, 'html.parser')
        topic_tags = soup.find_all('a', {'class': 'no-underline flex-1 d-flex flex-column'})
        
        if not topic_tags:
            print("No more topics found.")
            break
        
        for tag in topic_tags:
            topic_name = tag.find('p', {'class': 'f3 lh-condensed mb-0 mt-1 Link--primary'}).text.strip()
            topic_desc = tag.find('p', {'class': 'f5 color-fg-muted mb-0 mt-1'}).text.strip()
            topic_url = "https://github.com" + tag['href']
            topics.append({
                'name': topic_name,
                'normalized_name': normalize_topic_name(topic_name),
                'description': topic_desc,
                'url': topic_url
            })
        
        page += 1
    
    return topics

# %% [markdown]
# ## 🔌 Step 2: Fetching Top Repositories Using GitHub REST API
#
# I fetched the top 30 repositories for each topic sorted by stars using the GitHub REST API.

# %%
# Function to fetch top 30 repositories for a specific topic (with retry logic)
def get_top_repos_for_topic(topic, headers, max_retries=3):
    print(f"Fetching top 30 repositories for topic '{topic['name']}' (Normalized: '{topic['normalized_name']}') sorted by stars...")
    
    for attempt in range(max_retries):
        # Introduce a delay to avoid rate limiting
        time.sleep(2)  # Wait 2 seconds between requests
        
        response = requests.get(
            "https://api.github.com/search/repositories",
            params={"q": f"topic:{topic['normalized_name']}", "per_page": 30, "sort": "stars", "order": "desc"},
            headers=headers,
            timeout=10
        )
        print(f"Status Code: {response.status_code}")  # Debugging
        
        if response.status_code == 403:
            print("Rate limit exceeded. Pausing for 1 hour...")
            time.sleep(3600)  # Pause for 1 hour
            continue
        
        if response.status_code != 200:
            print(f"Error fetching repositories for topic '{topic['name']}': {response.json()}")
            continue
        
        data = response.json()
        items = data.get('items', [])
        if not items:
            print(f"No repositories found for topic '{topic['name']}' (Attempt {attempt + 1}/{max_retries})")
            continue
        
        return items
    
    print(f"Skipping topic '{topic['name']}' after {max_retries} failed attempts.")
    return []

# %%
# Function to extract repository details
def parse_repos(repos):
    repo_list = []
    for repo in repos:
        repo_list.append({
            'username': repo['owner']['login'],  # Repository owner's username
            'name': repo.get('name', None),      # Repository name
            'full_name': repo.get('full_name', None),  # Full name (owner/repo)
            'description': repo.get('description', None),
            'url': repo.get('html_url', None),   # Direct link to the repository
            'stars': repo.get('stargazers_count', 0),  # Number of stars
            'forks': repo.get('forks_count', 0),       # Number of forks
            'language': repo.get('language', None)     # Primary programming language
        })
    return pd.DataFrame(repo_list)

# %%
# Function to scrape top 30 repositories for all topics
def scrape_all_topics_repos():
    print('Fetching all topics from GitHub...')
    topics = get_all_topics()
    
    print(f"Found {len(topics)} topics.")
    
    # Add your GitHub token here
    headers = {
        'Authorization': 'token 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',
        'Accept': 'application/vnd.github.v3+json'
    }
    
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    output_dir = os.path.join('data', timestamp)
    os.makedirs(output_dir, exist_ok=True)
    print(f"Created/Verified directory: {output_dir}")
    
    skipped_topics = []  # Track skipped topics
    
    for topic in topics:
        try:
            # Fetch top 30 repositories for the topic
            repos = get_top_repos_for_topic(topic, headers)
            
            if not repos:
                print(f"No repositories found for topic '{topic['name']}' (Normalized: '{topic['normalized_name']}'). Skipping...")
                skipped_topics.append({
                    'original_name': topic['name'],
                    'normalized_name': topic['normalized_name']
                })
                continue
            
            # Parse repositories into a DataFrame
            repo_df = parse_repos(repos)
            
            # Save to CSV
            filename = f"{topic['name']}.csv"
            filepath = os.path.join(output_dir, filename)
            repo_df.to_csv(filepath, index=None)
            print(f"Saved data to {filepath}")
        except Exception as e:
            print(f"Error scraping topic '{topic['name']}': {e}")
            skipped_topics.append({
                'original_name': topic['name'],
                'normalized_name': topic['normalized_name']
            })
 # Log skipped topics
    if skipped_topics:
        print(f"\nSkipped the following topics due to errors or no repositories found:")
        for skipped_topic in skipped_topics:
            print(f"- Original Name: {skipped_topic['original_name']}, Normalized Name: {skipped_topic['normalized_name']}")

if __name__ == "__main__":
    scrape_all_topics_repos()
# Out:
# Fetching all topics from GitHub...
# Fetching topics from page 1...
# Fetching topics from page 2...
# Fetching topics from page 3...
# Fetching topics from page 4...
# Fetching topics from page 5...
# Fetching topics from page 6...
# Fetching topics from page 7...
# No more topics found.
# Found 164 topics.
# Created/Verified directory: data\20250418_205615
# Fetching top 30 repositories for topic '3D' (Normalized: '3d') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\3D.csv
# Fetching top 30 repositories for topic 'Ajax' (Normalized: 'ajax') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Ajax.csv
# Fetching top 30 repositories for topic 'Algorithm' (Normalized: 'algorithm') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Algorithm.csv
# Fetching top 30 repositories for topic 'Amp' (Normalized: 'amp') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Amp.csv
# Fetching top 30 repositories for topic 'Android' (Normalized: 'android') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Android.csv
# Fetching top 30 repositories for topic 'Angular' (Normalized: 'angular') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Angular.csv
# Fetching top 30 repositories for topic 'Ansible' (Normalized: 'ansible') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Ansible.csv
# Fetching top 30 repositories for topic 'API' (Normalized: 'api') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\API.csv
# Fetching top 30 repositories for topic 'Arduino' (Normalized: 'arduino') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Arduino.csv
# Fetching top 30 repositories for topic 'ASP.NET' (Normalized: 'asp-net') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\ASP.NET.csv
# Fetching top 30 repositories for topic 'Awesome Lists' (Normalized: 'awesome-lists') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Awesome Lists.csv
# Fetching top 30 repositories for topic 'Amazon Web Services' (Normalized: 'amazon-web-services') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Amazon Web Services.csv
# Fetching top 30 repositories for topic 'Azure' (Normalized: 'azure') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Azure.csv
# Fetching top 30 repositories for topic 'Babel' (Normalized: 'babel') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Babel.csv
# Fetching top 30 repositories for topic 'Bash' (Normalized: 'bash') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Bash.csv
# Fetching top 30 repositories for topic 'Bitcoin' (Normalized: 'bitcoin') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Bitcoin.csv
# Fetching top 30 repositories for topic 'Bootstrap' (Normalized: 'bootstrap') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Bootstrap.csv
# Fetching top 30 repositories for topic 'Bot' (Normalized: 'bot') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Bot.csv
# Fetching top 30 repositories for topic 'C' (Normalized: 'c') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\C.csv
# Fetching top 30 repositories for topic 'Chrome' (Normalized: 'chrome') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Chrome.csv
# Fetching top 30 repositories for topic 'Chrome extension' (Normalized: 'chrome-extension') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Chrome extension.csv
# Fetching top 30 repositories for topic 'Command-line interface' (Normalized: 'command-line-interface') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Command-line interface.csv
# Fetching top 30 repositories for topic 'Clojure' (Normalized: 'clojure') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Clojure.csv
# Fetching top 30 repositories for topic 'Code quality' (Normalized: 'code-quality') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Code quality.csv
# Fetching top 30 repositories for topic 'Code review' (Normalized: 'code-review') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Code review.csv
# Fetching top 30 repositories for topic 'Compiler' (Normalized: 'compiler') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Compiler.csv
# Fetching top 30 repositories for topic 'Continuous integration' (Normalized: 'continuous-integration') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Continuous integration.csv
# Fetching top 30 repositories for topic 'C++' (Normalized: 'c-plus-plus') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\C++.csv
# Fetching top 30 repositories for topic 'Cryptocurrency' (Normalized: 'cryptocurrency') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Cryptocurrency.csv
# Fetching top 30 repositories for topic 'Crystal' (Normalized: 'crystal') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Crystal.csv
# Fetching top 30 repositories for topic 'C#' (Normalized: 'c-sharp') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\C#.csv
# Fetching top 30 repositories for topic 'CSS' (Normalized: 'css') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\CSS.csv
# Fetching top 30 repositories for topic 'Data structures' (Normalized: 'data-structures') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Data structures.csv
# Fetching top 30 repositories for topic 'Data visualization' (Normalized: 'data-visualization') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Data visualization.csv
# Fetching top 30 repositories for topic 'Database' (Normalized: 'database') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Database.csv
# Fetching top 30 repositories for topic 'Deep learning' (Normalized: 'deep-learning') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Deep learning.csv
# Fetching top 30 repositories for topic 'Dependency management' (Normalized: 'dependency-management') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Dependency management.csv
# Fetching top 30 repositories for topic 'Deployment' (Normalized: 'deployment') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Deployment.csv
# Fetching top 30 repositories for topic 'Django' (Normalized: 'django') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Django.csv
# Fetching top 30 repositories for topic 'Docker' (Normalized: 'docker') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Docker.csv
# Fetching top 30 repositories for topic 'Documentation' (Normalized: 'documentation') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Documentation.csv
# Fetching top 30 repositories for topic '.NET' (Normalized: 'dotnet') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\.NET.csv
# Fetching top 30 repositories for topic 'Electron' (Normalized: 'electron') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Electron.csv
# Fetching top 30 repositories for topic 'Elixir' (Normalized: 'elixir') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Elixir.csv
# Fetching top 30 repositories for topic 'Emacs' (Normalized: 'emacs') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Emacs.csv
# Fetching top 30 repositories for topic 'Ember' (Normalized: 'ember') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Ember.csv
# Fetching top 30 repositories for topic 'Emoji' (Normalized: 'emoji') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Emoji.csv
# Fetching top 30 repositories for topic 'Emulator' (Normalized: 'emulator') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Emulator.csv
# Fetching top 30 repositories for topic 'ESLint' (Normalized: 'eslint') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\ESLint.csv
# Fetching top 30 repositories for topic 'Ethereum' (Normalized: 'ethereum') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Ethereum.csv
# Fetching top 30 repositories for topic 'Express' (Normalized: 'express') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Express.csv
# Fetching top 30 repositories for topic 'Firebase' (Normalized: 'firebase') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Firebase.csv
# Fetching top 30 repositories for topic 'Firefox' (Normalized: 'firefox') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Firefox.csv
# Fetching top 30 repositories for topic 'Flask' (Normalized: 'flask') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Flask.csv
# Fetching top 30 repositories for topic 'Font' (Normalized: 'font') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Font.csv
# Fetching top 30 repositories for topic 'Framework' (Normalized: 'framework') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Framework.csv
# Fetching top 30 repositories for topic 'Front end' (Normalized: 'front-end') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Front end.csv
# Fetching top 30 repositories for topic 'Game engine' (Normalized: 'game-engine') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Game engine.csv
# Fetching top 30 repositories for topic 'Git' (Normalized: 'git') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Git.csv
# Fetching top 30 repositories for topic 'GitHub API' (Normalized: 'github-api') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\GitHub API.csv
# Fetching top 30 repositories for topic 'Go' (Normalized: 'go') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Go.csv
# Fetching top 30 repositories for topic 'Google' (Normalized: 'google') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Google.csv
# Fetching top 30 repositories for topic 'Gradle' (Normalized: 'gradle') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Gradle.csv
# Fetching top 30 repositories for topic 'GraphQL' (Normalized: 'graphql') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\GraphQL.csv
# Fetching top 30 repositories for topic 'Gulp' (Normalized: 'gulp') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Gulp.csv
# Fetching top 30 repositories for topic 'Hacktoberfest' (Normalized: 'hacktoberfest') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Hacktoberfest.csv
# Fetching top 30 repositories for topic 'Haskell' (Normalized: 'haskell') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Haskell.csv
# Fetching top 30 repositories for topic 'Homebrew' (Normalized: 'homebrew') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Homebrew.csv
# Fetching top 30 repositories for topic 'Homebridge' (Normalized: 'homebridge') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Homebridge.csv
# Fetching top 30 repositories for topic 'HTML' (Normalized: 'html') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\HTML.csv
# Fetching top 30 repositories for topic 'HTTP' (Normalized: 'http') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\HTTP.csv
# Fetching top 30 repositories for topic 'Icon font' (Normalized: 'icon-font') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Icon font.csv
# Fetching top 30 repositories for topic 'iOS' (Normalized: 'ios') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\iOS.csv
# Fetching top 30 repositories for topic 'IPFS' (Normalized: 'ipfs') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\IPFS.csv
# Fetching top 30 repositories for topic 'Java' (Normalized: 'java') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Java.csv
# Fetching top 30 repositories for topic 'JavaScript' (Normalized: 'javascript') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\JavaScript.csv
# Fetching top 30 repositories for topic 'Jekyll' (Normalized: 'jekyll') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Jekyll.csv
# Fetching top 30 repositories for topic 'jQuery' (Normalized: 'jquery') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\jQuery.csv
# Fetching top 30 repositories for topic 'JSON' (Normalized: 'json') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\JSON.csv
# Fetching top 30 repositories for topic 'The Julia Language' (Normalized: 'julia') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\The Julia Language.csv
# Fetching top 30 repositories for topic 'Jupyter Notebook' (Normalized: 'jupyter-notebook') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Jupyter Notebook.csv
# Fetching top 30 repositories for topic 'Koa' (Normalized: 'koa') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Koa.csv
# Fetching top 30 repositories for topic 'Kotlin' (Normalized: 'kotlin') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Kotlin.csv
# Fetching top 30 repositories for topic 'Kubernetes' (Normalized: 'kubernetes') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Kubernetes.csv
# Fetching top 30 repositories for topic 'Laravel' (Normalized: 'laravel') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Laravel.csv
# Fetching top 30 repositories for topic 'LaTeX' (Normalized: 'latex') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\LaTeX.csv
# Fetching top 30 repositories for topic 'Library' (Normalized: 'library') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Library.csv
# Fetching top 30 repositories for topic 'Linux' (Normalized: 'linux') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Linux.csv
# Fetching top 30 repositories for topic 'Localization (l10n)' (Normalized: 'localization-(l10n)') sorted by stars...
# Status Code: 200
# No repositories found for topic 'Localization (l10n)' (Attempt 1/3)
# Status Code: 200
# No repositories found for topic 'Localization (l10n)' (Attempt 2/3)
# Status Code: 200
# No repositories found for topic 'Localization (l10n)' (Attempt 3/3)
# Skipping topic 'Localization (l10n)' after 3 failed attempts.
# No repositories found for topic 'Localization (l10n)' (Normalized: 'localization-(l10n)'). Skipping...
# Fetching top 30 repositories for topic 'Lua' (Normalized: 'lua') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Lua.csv
# Fetching top 30 repositories for topic 'Machine learning' (Normalized: 'machine-learning') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Machine learning.csv
# Fetching top 30 repositories for topic 'macOS' (Normalized: 'macos') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\macOS.csv
# Fetching top 30 repositories for topic 'Markdown' (Normalized: 'markdown') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Markdown.csv
# Fetching top 30 repositories for topic 'Mastodon' (Normalized: 'mastodon') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Mastodon.csv
# Fetching top 30 repositories for topic 'Material Design' (Normalized: 'material-design') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Material Design.csv
# Fetching top 30 repositories for topic 'MATLAB' (Normalized: 'matlab') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\MATLAB.csv
# Fetching top 30 repositories for topic 'Maven' (Normalized: 'maven') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Maven.csv
# Fetching top 30 repositories for topic 'Minecraft' (Normalized: 'minecraft') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Minecraft.csv
# Fetching top 30 repositories for topic 'Mobile' (Normalized: 'mobile') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Mobile.csv
# Fetching top 30 repositories for topic 'Monero' (Normalized: 'monero') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Monero.csv
# Fetching top 30 repositories for topic 'MongoDB' (Normalized: 'mongodb') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\MongoDB.csv
# Fetching top 30 repositories for topic 'Mongoose' (Normalized: 'mongoose') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Mongoose.csv
# Fetching top 30 repositories for topic 'Monitoring' (Normalized: 'monitoring') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Monitoring.csv
# Fetching top 30 repositories for topic 'MvvmCross' (Normalized: 'mvvmcross') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\MvvmCross.csv
# Fetching top 30 repositories for topic 'MySQL' (Normalized: 'mysql') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\MySQL.csv
# Fetching top 30 repositories for topic 'NativeScript' (Normalized: 'nativescript') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\NativeScript.csv
# Fetching top 30 repositories for topic 'Nim' (Normalized: 'nim') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Nim.csv
# Fetching top 30 repositories for topic 'Natural language processing' (Normalized: 'natural-language-processing') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Natural language processing.csv
# Fetching top 30 repositories for topic 'Node.js' (Normalized: 'nodejs') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Node.js.csv
# Fetching top 30 repositories for topic 'NoSQL' (Normalized: 'nosql') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\NoSQL.csv
# Fetching top 30 repositories for topic 'npm' (Normalized: 'npm') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\npm.csv
# Fetching top 30 repositories for topic 'Objective-C' (Normalized: 'objective-c') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Objective-C.csv
# Fetching top 30 repositories for topic 'OpenGL' (Normalized: 'opengl') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\OpenGL.csv
# Fetching top 30 repositories for topic 'Operating system' (Normalized: 'operating-system') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Operating system.csv
# Fetching top 30 repositories for topic 'P2P' (Normalized: 'p2p') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\P2P.csv
# Fetching top 30 repositories for topic 'Package manager' (Normalized: 'package-manager') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Package manager.csv
# Fetching top 30 repositories for topic 'Parsing' (Normalized: 'parsing') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Parsing.csv
# Fetching top 30 repositories for topic 'Perl' (Normalized: 'perl') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Perl.csv
# Fetching top 30 repositories for topic 'Phaser' (Normalized: 'phaser') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Phaser.csv
# Fetching top 30 repositories for topic 'PHP' (Normalized: 'php') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\PHP.csv
# Fetching top 30 repositories for topic 'PICO-8' (Normalized: 'pico-8') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\PICO-8.csv
# Fetching top 30 repositories for topic 'Pixel Art' (Normalized: 'pixel-art') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Pixel Art.csv
# Fetching top 30 repositories for topic 'PostgreSQL' (Normalized: 'postgresql') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\PostgreSQL.csv
# Fetching top 30 repositories for topic 'Project management' (Normalized: 'project-management') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Project management.csv
# Fetching top 30 repositories for topic 'Publishing' (Normalized: 'publishing') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Publishing.csv
# Fetching top 30 repositories for topic 'PWA' (Normalized: 'pwa') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\PWA.csv
# Fetching top 30 repositories for topic 'Python' (Normalized: 'python') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Python.csv
# Fetching top 30 repositories for topic 'Qt' (Normalized: 'qt') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Qt.csv
# Fetching top 30 repositories for topic 'R' (Normalized: 'r') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\R.csv
# Fetching top 30 repositories for topic 'Rails' (Normalized: 'rails') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Rails.csv
# Fetching top 30 repositories for topic 'Raspberry Pi' (Normalized: 'raspberry-pi') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Raspberry Pi.csv
# Fetching top 30 repositories for topic 'Ratchet' (Normalized: 'ratchet') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Ratchet.csv
# Fetching top 30 repositories for topic 'React' (Normalized: 'react') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\React.csv
# Fetching top 30 repositories for topic 'React Native' (Normalized: 'react-native') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\React Native.csv
# Fetching top 30 repositories for topic 'ReactiveUI' (Normalized: 'reactiveui') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\ReactiveUI.csv
# Fetching top 30 repositories for topic 'Redux' (Normalized: 'redux') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Redux.csv
# Fetching top 30 repositories for topic 'REST API' (Normalized: 'rest-api') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\REST API.csv
# Fetching top 30 repositories for topic 'Ruby' (Normalized: 'ruby') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Ruby.csv
# Fetching top 30 repositories for topic 'Rust' (Normalized: 'rust') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Rust.csv
# Fetching top 30 repositories for topic 'Sass' (Normalized: 'sass') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Sass.csv
# Fetching top 30 repositories for topic 'Scala' (Normalized: 'scala') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Scala.csv
# Fetching top 30 repositories for topic 'scikit-learn' (Normalized: 'scikit-learn') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\scikit-learn.csv
# Fetching top 30 repositories for topic 'Software-defined networking' (Normalized: 'sdn') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Software-defined networking.csv
# Fetching top 30 repositories for topic 'Security' (Normalized: 'security') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Security.csv
# Fetching top 30 repositories for topic 'Server' (Normalized: 'server') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Server.csv
# Fetching top 30 repositories for topic 'Serverless' (Normalized: 'serverless') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Serverless.csv
# Fetching top 30 repositories for topic 'Shell' (Normalized: 'shell') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Shell.csv
# Fetching top 30 repositories for topic 'Sketch' (Normalized: 'sketch') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Sketch.csv
# Fetching top 30 repositories for topic 'SpaceVim' (Normalized: 'spacevim') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\SpaceVim.csv
# Fetching top 30 repositories for topic 'Spring Boot' (Normalized: 'spring-boot') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Spring Boot.csv
# Fetching top 30 repositories for topic 'SQL' (Normalized: 'sql') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\SQL.csv
# Fetching top 30 repositories for topic 'Storybook' (Normalized: 'storybook') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Storybook.csv
# Fetching top 30 repositories for topic 'Support' (Normalized: 'support') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Support.csv
# Fetching top 30 repositories for topic 'Swift' (Normalized: 'swift') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Swift.csv
# Fetching top 30 repositories for topic 'Symfony' (Normalized: 'symfony') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Symfony.csv
# Fetching top 30 repositories for topic 'Telegram' (Normalized: 'telegram') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Telegram.csv
# Fetching top 30 repositories for topic 'Tensorflow' (Normalized: 'tensorflow') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Tensorflow.csv
# Fetching top 30 repositories for topic 'Terminal' (Normalized: 'terminal') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Terminal.csv
# Fetching top 30 repositories for topic 'Terraform' (Normalized: 'terraform') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Terraform.csv
# Fetching top 30 repositories for topic 'Testing' (Normalized: 'testing') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Testing.csv
# Fetching top 30 repositories for topic 'X (Twitter)' (Normalized: 'x-(twitter)') sorted by stars...
# Status Code: 200
# No repositories found for topic 'X (Twitter)' (Attempt 1/3)
# Status Code: 200
# No repositories found for topic 'X (Twitter)' (Attempt 2/3)
# Status Code: 200
# No repositories found for topic 'X (Twitter)' (Attempt 3/3)
# Skipping topic 'X (Twitter)' after 3 failed attempts.
# No repositories found for topic 'X (Twitter)' (Normalized: 'x-(twitter)'). Skipping...
# Fetching top 30 repositories for topic 'TypeScript' (Normalized: 'typescript') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\TypeScript.csv
# Fetching top 30 repositories for topic 'Ubuntu' (Normalized: 'ubuntu') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Ubuntu.csv
# Fetching top 30 repositories for topic 'Unity' (Normalized: 'unity') sorted by stars...
# Status Code: 200
# Saved data to data\20250418_205615\Unity.csv
#
# Skipped the following topics due to errors or no repositories found:
# - Original Name: Localization (l10n), Normalized Name: localization-(l10n)
# - Original Name: X (Twitter), Normalized Name: x-(twitter)

# %% [markdown]
# ## 📁 Step 3: Merge CSV Files Into One Master File
#
# Once scraping was done, I merged all CSV files into a single dataset using Python(Pandas) for Power BI.

# %%
import os
import pandas as pd

# Directory containing the CSV files
input_dir = r"C:\Users\welcome\data\Final data"  # Replace with your folder path

# Output file name
output_file = os.path.join(input_dir, "merged_repositories.csv")

# List to store individual DataFrames
all_data = []

# Check if the directory exists
if not os.path.exists(input_dir):
    raise FileNotFoundError(f"The directory '{input_dir}' does not exist.")

# Loop through all files in the directory
for filename in os.listdir(input_dir):
    if filename.endswith(".csv"):  # Process only CSV files
        try:
            # Extract the topic name from the filename (remove the .csv extension)
            topic_name = os.path.splitext(filename)[0]
            
            # Construct the full file path
            file_path = os.path.join(input_dir, filename)
            
            # Debug: Print the file being processed
            print(f"Processing file: {file_path}")
            
            # Read the CSV file into a DataFrame
            df = pd.read_csv(file_path)
            
            # Add a new column for the topic name
            df["Repositery"] = topic_name  # Note: "Repositery" is intentionally misspelled
            
            # Append the DataFrame to the list
            all_data.append(df)
        except Exception as e:
            print(f"Error processing file '{filename}': {e}")

# Check if any DataFrames were added to the list
if not all_data:
    raise ValueError("No valid CSV files found to process.")

# Concatenate all DataFrames into a single DataFrame
merged_df = pd.concat(all_data, ignore_index=True)

# Reorder columns to match your desired format
merged_df = merged_df[["Repositery", "username", "name", "full_name", "description", "url", "stars", "forks", "language"]]

# Save the merged DataFrame to a new CSV file
merged_df.to_csv(output_file, index=False)

print(f"Merged data saved to {output_file}")
# Out:
# Processing file: C:\Users\welcome\data\Final data\.NET.csv
# Processing file: C:\Users\welcome\data\Final data\3D.csv
# Processing file: C:\Users\welcome\data\Final data\Ajax.csv
# Processing file: C:\Users\welcome\data\Final data\Algorithm.csv
# Processing file: C:\Users\welcome\data\Final data\Amazon Web Services.csv
# Processing file: C:\Users\welcome\data\Final data\Amp.csv
# Processing file: C:\Users\welcome\data\Final data\Android.csv
# Processing file: C:\Users\welcome\data\Final data\Angular.csv
# Processing file: C:\Users\welcome\data\Final data\Ansible.csv
# Processing file: C:\Users\welcome\data\Final data\API.csv
# Processing file: C:\Users\welcome\data\Final data\Arduino.csv
# Processing file: C:\Users\welcome\data\Final data\ASP.NET.csv
# Processing file: C:\Users\welcome\data\Final data\Awesome Lists.csv
# Processing file: C:\Users\welcome\data\Final data\Azure.csv
# Processing file: C:\Users\welcome\data\Final data\Babel.csv
# Processing file: C:\Users\welcome\data\Final data\Bash.csv
# Processing file: C:\Users\welcome\data\Final data\Bitcoin.csv
